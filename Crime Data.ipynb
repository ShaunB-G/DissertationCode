# %%
#Data from: hate-crime-england-and-wales-2022-to-2023-data-tables-second-edition.ods

# %%
#Import libraries 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import seaborn as sns

# Define filepath
filepath = 'hate-crime-england-and-wales-2022-to-2023-data-tables-second-edition.ods'

#Create df from Annual Hate crime data
Annualdf = pd.read_excel(filepath, header=1, sheet_name= "2", usecols="A,B,C,E,G,H,I,J,K,L,M", skiprows=4, nrows=7)

# %%
Annualdf
# Out:
#                     Hate crime strand 2011/12  2012/13  2014/15  2016/17  \
# 0                                Race   35207    35115    42204    61945
# 1                            Religion    1607     1557     3272     5879
# 2                  Sexual orientation    4292     4119     5465     9020
# 3                          Disability    1741     1838     2476     5453
# 4                         Transgender     310      343      591     1221
# 5  Total number of motivating factors   43157    42972    54008    83518
# 6           Total number of offences      [x]    41294    51612    79432
#
#    2017/18  2018/19  2019/20   2020/21  2021/22  2022/23
# 0    70332     77850      [x]    90909   108476   101906
# 1     8248      8460      [x]     6288     8602     8241
# 2    11351     14161      [x]    18239    25639    24102
# 3     7027      8052      [x]     9690    13905    13777
# 4     1653      2253      [x]     2728     4262     4732
# ...

# %%
#Crime rates per year vs hate tweets
